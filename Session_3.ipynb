# %% [markdown]
# <a href="https://colab.research.google.com/github/MAlhammadi0/MAlhammadi0/blob/main/Session_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("t")
# Out:
# t
